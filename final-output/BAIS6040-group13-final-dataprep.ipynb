# %% [markdown]
# # **Real Estate Regression**
# ## **Predicting Residential Real Estate Sale Price in Polk County Based On Selected Features**
# ### *Data Programming with Python - Group 13 Project*
# ### *Eric Schelin, Navin Mukraj, Sean O'Bryan*
# #### Notebook for data preparation
#
# <hr size=8>
#
# <img align="right" src="https://www.python.org/static/community_logos/python-logo.png">
# <img align="left" src="https://www.dsm.city/_assets_/images/logo.png">

# %% [markdown]
# ## Table of contents
# ***
# 1. Download the data
#     - Get each year of data from Polk county
#     - Read each year of data from csv to a single dataframe
#     - Export the combined dataframe to a single csv
#     - Execute the functions to download the data
# 2. Prepare the dataframe
#     - Create column with four digit sale year from sale date
#     - Drop nulls from column 'year_built' and convert to int
#     - Convert total living area to int
#     - Adjust sale price for inflation
#      - Split the data from before 2019 that needs to be adjusted
#      - Install and update library 'cpi'
#      - Load a function to adjust the price of a given column
#      - Create a new column of adjusted price from the sale price of a home
#      - Convert adjusted price to int
#      - Merge both dataframes back to a single dataframe
# 3. Visualizations
#     - Present correlation matrix
#     - Evalute features based on matrix. Of these, select three features of interest: 'bathrooms','year_built', and 'total_living_area'
#     - Noteworthy - Correlation of school discrict category code vs correlation of individual school districts
#     - Remove any incomplete observations in the selected features datatable
#     - Present correlation matrix that contains selected features and target
#     - Present histogram of selected features
#     - Present histogram of year built
# 4. Export the prepared data
#     - Export the dataframe that was prepared for regression

# %% [markdown]
# ### Download the data

# %%
# install wget
# !pip install wget
# Out:
# Requirement already satisfied: wget in c:\users\user2\anaconda3\lib\site-packages (3.2)
# Error processing line 7 of c:\users\user2\anaconda3\lib\site-packages\pywin32.pth:
#
#   Traceback (most recent call last):
#     File "c:\users\user2\anaconda3\lib\site.py", line 168, in addpackage
#       exec(line)
#     File "<string>", line 1, in <module>
#   ModuleNotFoundError: No module named 'pywin32_bootstrap'
#
# Remainder of file ignored

# %% [markdown]
# #### Get each year of data from Polk county

# %%
# %%time

# http://web.assess.co.polk.ia.us/web/exports/resA/sales/2020.txt
# download all the files for all POLK
# takes about 1min30secs
import wget
import os

from datetime import date

def download_polk_res_sales(overwrite=False):
    if overwrite:
        min_year = 1990
        max_year = date.today().year
        # base url with the year as a placeholder
        # base_url = "http://web.assess.co.polk.ia.us/web/exports/res/sales/{}/DM.txt"
        base_url = "http://web.assess.co.polk.ia.us/web/exports/resA/sales/{}.txt"
        # base name
        base_name = "POLK-{}.csv"

        for year in range(min_year,max_year+1):
            url = base_url.format(year)
            name = base_name.format(year)
            path = "./data/{}".format(name)
            if os.path.exists(path):
                os.remove(path) 
            wget.download(url,path)
# Out:
# Wall time: 0 ns

# %% [markdown]
# #### Read each year of data from csv to a single dataframe

# %%
# %%time
# read real estate from the downloaded files
# download the files first
# this takes about 1.5secs

import pandas as pd
from datetime import date

def import_all_polk_res_sales_from_csv():
    min_year = 1990
    max_year = date.today().year
    # base url with the year as a placeholder
    base_url = "./data/POLK-{}.csv"

    # list of csv location by year
    urls = list(map(lambda x: base_url.format(x), range(min_year,max_year+1)))
    # this took 1min 30s
    # read in all the tab delimited csv's into a dataframe
    df_import = pd.concat((pd.read_csv(url, sep="\t") for url in urls))

    df_import.shape
    return df_import
# Out:
# Wall time: 0 ns

# %% [markdown]
# #### Export the combined dataframe to a single csv

# %%
def export_to_csv(df_to_export,overwrite=False,export_location="./data/POLK-all-years.csv"):
    if overwrite:
        # delete if exists
        if os.path.exists(export_location):
            os.remove(export_location) 
        # export to csv
        df_to_export.to_csv(export_location)

# %% [markdown]
# #### Execute the functions to download the data

# %%
# This takes three to five minutes, depending on your download speed.
download_polk_res_sales(True)
df = import_all_polk_res_sales_from_csv()
export_all_polk_res_sales_to_csv(df,overwrite=True)
# Out:
# 100% [..........................................................................] 4847492 / 4847492
# C:\Users\user2\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: DtypeWarning: Columns (74) have mixed types.Specify dtype option on import or set low_memory=False.
# C:\Users\user2\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: DtypeWarning: Columns (67,74) have mixed types.Specify dtype option on import or set low_memory=False.
# C:\Users\user2\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: DtypeWarning: Columns (67) have mixed types.Specify dtype option on import or set low_memory=False.

# %% [markdown]
# ### Prepare the dataframe

# %% [markdown]
# #### Create column with four digit sale year from sale date

# %%
# Create column with four digit sale year
df['sale_date'] =  pd.to_datetime(df['sale_date'])
df['sale_year'] = pd.DatetimeIndex(df['sale_date']).year

# %% [markdown]
# #### Drop nulls from column 'year_built' and convert to int

# %%
import numpy as np
# convert year_built to int
df.dropna(subset=['year_built'], inplace=True)
print("Previous type: {}".format(df.year_built.dtypes))
df["year_built"] = df["year_built"].astype(np.int64)
print("New type: {}".format(df.year_built.dtypes))
# Out:
# Previous type: float64
# New type: int64

# %% [markdown]
# #### Convert total living area to int

# %%
print("Previous type: {}".format(df.total_living_area.dtypes))
df.total_living_area = df.total_living_area.astype(np.int64)
print("New type: {}".format(df.total_living_area.dtypes))
# Out:
# Previous type: float64
# New type: int64

# %% [markdown]
# #### Adjust sale price for inflation

# %% [markdown]
# ##### Split the data from before 2019 that needs to be adjusted

# %%
# split data that needs to be adjusted for cpi
# with no nulls - adjust for cpi
df_2020 = df[df.sale_year > 2018]
df_need_adj = df[df.sale_year < 2019]

# Testing - validating results
# print("Total: {}".format(df.shape[0]))
# print("2020: {}".format(df_2020.shape[0]))
# print("need adj: {}".format(df_need_adj.shape[0]))
# print("sum of 2020 and need adj: {}".format((df_need_adj.shape[0]+df_2020.shape[0]+df['year_built'].isnull().sum())))
# print(df['year_built'].isnull().sum())

# %% [markdown]
# ##### Install and update library 'cpi'

# %%
# !pip install cpi
import cpi
cpi.update
# Out:
# Requirement already satisfied: cpi in c:\users\user2\anaconda3\lib\site-packages (0.1.16)
# Requirement already satisfied: pandas>=0.23.1 in c:\users\user2\anaconda3\lib\site-packages (from cpi) (1.1.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\user2\anaconda3\lib\site-packages (from cpi) (2.8.1)
# Requirement already satisfied: requests>=2.20.0 in c:\users\user2\anaconda3\lib\site-packages (from cpi) (2.24.0)
# Requirement already satisfied: click>=6.7 in c:\users\user2\anaconda3\lib\site-packages (from cpi) (7.1.2)
# Requirement already satisfied: pytz>=2017.2 in c:\users\user2\anaconda3\lib\site-packages (from pandas>=0.23.1->cpi) (2020.1)
# Requirement already satisfied: numpy>=1.15.4 in c:\users\user2\anaconda3\lib\site-packages (from pandas>=0.23.1->cpi) (1.18.5)
# Requirement already satisfied: six>=1.5 in c:\users\user2\anaconda3\lib\site-packages (from python-dateutil>=2.7.3->cpi) (1.15.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\user2\anaconda3\lib\site-packages (from requests>=2.20.0->cpi) (2020.6.20)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\user2\anaconda3\lib\site-packages (from requests>=2.20.0->cpi) (2.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\user2\anaconda3\lib\site-packages (from requests>=2.20.0->cpi) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\user2\anaconda3\lib\site-packages (from requests>=2.20.0->cpi) (1.25.11)
# Error processing line 7 of c:\users\user2\anaconda3\lib\site-packages\pywin32.pth:
#
#   Traceback (most recent call last):
#     File "c:\users\user2\anaconda3\lib\site.py", line 168, in addpackage
#       exec(line)
#     File "<string>", line 1, in <module>
#   ModuleNotFoundError: No module named 'pywin32_bootstrap'
#
# Remainder of file ignored
# C:\Users\user2\Anaconda3\lib\site-packages\cpi\__init__.py:46: StaleDataWarning: CPI data is out of date. To accurately inflate to today's dollars, you must run `cpi.update()`.
#   warnings.warn(StaleDataWarning())
# <function cpi.update()>

# %% [markdown]
# ##### Load a function to adjust the price of a given column

# %%
def inflate_column(data, price, year):
    return data.apply(lambda x: cpi.inflate(x[price], 
                      x[year]), axis=1)

# %% [markdown]
# ##### Create a new column of adjusted price from the sale price of a home

# %%
# adjust the sale price column "price" for inflation based on the column "sale_year" 
df_need_adj["price_adj"] = inflate_column(df_need_adj,'price','sale_year')
# Out:
# C:\Users\user2\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %% [markdown]
# ##### Convert the adjusted price column to an int

# %%
print("Previous type: {}".format(df_need_adj["price_adj"].dtype))
df_need_adj["price_adj"] = df_need_adj["price_adj"].astype(np.int64)
print("New type: {}".format(df_need_adj["price_adj"].dtype))
# Out:
# Previous type: float64
# New type: int64
# C:\Users\user2\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %% [markdown]
# ##### Merge both dataframes back to a single dataframe

# %%
# combine and fill in the 2019,2020 values with non-adjusted price
df4 = pd.concat([df_need_adj,df_2020])

# print(df4['price_adj'].isnull().sum())
# print(df_2020.shape[0])

df4.price_adj = df4.price_adj.fillna(value=df4.price)
# print(df4['price_adj'].isnull().sum())

# finally replace our working object with the transformed object
df = df4

# %%
df.school_district = pd.Categorical(df.school_district)
df.school_district_codes = df.school_district.cat.codes
# Out:
# C:\Users\user2\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access

# %%
# df = pd.concat([df.drop("school_district",axis=1), pd.get_dummies(df.school_district)], axis = 1)
df = pd.concat([df, pd.get_dummies(df.school_district)], axis = 1)
df.head()
# Out:
#    jurisdiction  nbhd              dp            gp  sale_date  book   pg  \
# 5        ANKENY  AK02  18100027000000           NaN 1990-03-14  6213  278
# 7        ANKENY  AK02  18100072001000  8.024231e+11 1990-09-26  6307  786
# 9        ANKENY  AK02  18100097024019  8.024254e+11 1990-06-15  6255  306
# 11       ANKENY  AK02  18100111000000  8.024232e+11 1990-10-17  6298  916
# 12       ANKENY  AK02  18100121000000  8.024232e+11 1990-06-13  6248  716
#
#    instrument   price             address  ...  Des Moines Johnston Madrid  \
# 5        Deed  104000  410 SW ORDNANCE RD  ...           0        0      0
# 7        Deed   38900      1133 SW 3RD ST  ...           0        0      0
# 9    Contract  200000     7983 NE 14TH ST  ...           0        0      0
# 11   Contract   43200    101 SW CHERRY ST  ...           0        0      0
#T_17704040_1cba_11eb_9853_5c879ca494carow32_col52,#T_17704040_1cba_11eb_9853_5c879ca494carow36_col57,#T_17704040_1cba_11eb_9853_5c879ca494carow37_col47,#T_17704040_1cba_11eb_9853_5c879ca494carow37_col57,#T_17704040_1cba_11eb_9853_5c879ca494carow38_col20,#T_17704040_1cba_11eb_9853_5c879ca494carow42_col57,#T_17704040_1cba_11eb_9853_5c879ca494carow44_col56,#T_17704040_1cba_11eb_9853_5c879ca494carow51_col9,#T_17704040_1cba_11eb_9853_5c879ca494carow51_col10,#T_17704040_1cba_11eb_9853_5c879ca494carow51_col38,#T_17704040_1cba_11eb_9853_5c879ca494carow51_col44,#T_17704040_1cba_11eb_9853_5c879ca494carow51_col57,#T_17704040_1cba_11eb_9853_5c879ca494carow53_col56,#T_17704040_1cba_11eb_9853_5c879ca494carow53_col57,#T_17704040_1cba_11eb_9853_5c879ca494carow54_col1,#T_17704040_1cba

# %% [markdown]
# #### Evalute features based on matrix. Of these, select three features of interest: 'bathrooms','year_built', and 'total_living_area'

# %%
df2 = df[['price_adj','bathrooms','year_built','total_living_area']].copy()
pd.set_option('display.max_rows',100)

# for testing
# based on correlation matrix, copy highly correlated features
# df2 = df[['price','price_adj','land_full','bldg_full','total_full','main_living_area',
#           'total_living_area','basement_area','att_garage_area','bathrooms',
#           'extra_fixtures','fireplaces','year_built','sale_date','sale_year','adjusted_psf']].copy()

# %% [markdown]
# ##### Noteworthy - Correlation of school discrict category code vs correlation of individual school districts
# The correlation is between price and school districts category codes is almost 0.
# The correlation between specific school districts of Ankeny, Johnston, West Des Moines, and Des Moines have a correlation to price.

# %%
df_schools = df[['price_adj', 'school_district']]
df_schools.school_district = df.school_district.cat.codes

df_schools = pd.concat([df_schools,pd.get_dummies(df.school_district)], axis = 1)
# Out:
# C:\Users\user2\Anaconda3\lib\site-packages\pandas\core\generic.py:5168: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %%
df_schools.corr().style.background_gradient(cmap='coolwarm').set_precision(2)
# Out:
# <style  type="text/css" >
# #T_32617d86_1cba_11eb_81b3_5c879ca494carow0_col0,#T_32617d86_1cba_11eb_81b3_5c879ca494carow1_col1,#T_32617d86_1cba_11eb_81b3_5c879ca494carow2_col2,#T_32617d86_1cba_11eb_81b3_5c879ca494carow3_col3,#T_32617d86_1cba_11eb_81b3_5c879ca494carow4_col4,#T_32617d86_1cba_11eb_81b3_5c879ca494carow5_col5,#T_32617d86_1cba_11eb_81b3_5c879ca494carow6_col6,#T_32617d86_1cba_11eb_81b3_5c879ca494carow7_col7,#T_32617d86_1cba_11eb_81b3_5c879ca494carow8_col8,#T_32617d86_1cba_11eb_81b3_5c879ca494carow9_col9,#T_32617d86_1cba_11eb_81b3_5c879ca494carow10_col10,#T_32617d86_1cba_11eb_81b3_5c879ca494carow11_col11,#T_32617d86_1cba_11eb_81b3_5c879ca494carow12_col12,#T_32617d86_1cba_11eb_81b3_5c879ca494carow13_col13,#T_32617d86_1cba_11eb_81b3_5c879ca494carow14_col14,#T_32617d86_1cba_11eb_81b3_5c879ca494carow15_col15,#T_32617d86_1cba_11eb_81b3_5c879ca494carow16_col16,#T_32617d86_1cba_11eb_81b3_5c879ca494carow17_col17,#T_32617d86_1cba_11eb_81b3_5c879ca494carow18_col18,#T_32617d86_1cba_11eb_81b3_5c879ca494carow19_col19,#T_32617d86_1cba_11eb_81b3_5c879ca494carow20_col20{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T

#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }#T_3600c6a6_1cba_11eb_b63a_5c879ca494carow3_col0{
#             background-color:  #bcd2f7;
#             color:  #000000;
#         }#T_3600c6a6_1cba_11eb_b63a_5c879ca494carow3_col1{
#             background-color:  #80a3fa;
#             color:  #000000;
#         }</style><table id="T_3600c6a6_1cba_11eb_b63a_5c879ca494ca" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >price_adj</th>        <th class="col_heading level0 col1" >bathrooms</th>        <th class="col_heading level0 col2" >year_built</th>        <th class="col_heading level0 col3" >total_living_area</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_3600c6a6_1cba_11eb_b63a_5c879ca494calevel0_row0" class="row_heading level0 row0" >price_adj</th>
#                         <td id="T_3600c6a6_1cba_11eb_b63a_5c879ca494carow0_col0" class="data row0 col0" >1.00</td>
#                         <td id="T_3600c6a6_1cba_11eb_b63a_5c879ca494carow0_col1" class="data row0 col1" >0.61</td>
#                         <td id="T_3600c6a6_1cba_11eb_b63a_5c879ca494carow0_col2" class="data row0 col2" >0.50</td>
#                         <td id="T_3600c6a6_1cba_11eb_b63a_5c879ca494carow0_col3" class="data row0 col3" >0.69</td>
#             </tr>
#             <tr>
#                         <th id="T_3600c6a6_1cba_11eb_b63a_5c879ca494calevel0_row1" class="row_heading level0 row1" >bathrooms</th>
#                         <td id="T_3600c6a6_1cba_11eb_b63a_5c879ca494carow1_col0" class="data row1 col0" >0.61</td>
#                         <td id="T_3600c6a6_1cba_11eb_b63a_5c879ca494carow1_col1" class="data row1 col1" >1.00</td>
#                         <td id="T_3600c6a6_1cba_11eb_b63a_5c879ca494carow1_col2" class="data row1 col2" >0.53</td>
#                         <td id="T_3600c6a6_1cba_11eb_b63a_5c879ca494carow1_col3" class="data row1 col3" >0.63</td>
#             </tr>
#             <tr>
#                         <th id="T_3600c6a6_1cba_11eb_b63a_5c879ca494calevel0_row2" class="row_heading level0 row2" >year_built</th>
#                         <td id="T_3600c6a6_1cba_11eb_b63a_5c879ca494carow2_col0" class="data row2 col0" >0.50</td>
#                         <td id="T_3600c6a6_1cba_11eb_b63a_5c879ca494carow2_col1" class="data row2 col1" >0.53</td>
#                         <td id="T_3600c6a6_1cba_11eb_b63a_5c879ca494carow2_col2" class="data row2 col2" >1.00</td>
#                         <td id="T_3600c6a6_1cba_11eb_b63a_5c879ca494carow2_col3" class="data row2 col3" >0.32</td>
#             </tr>
#             <tr>
#                         <th id="T_3600c6a6_1cba_11eb_b63a_5c879ca494calevel0_row3" class="row_heading level0 row3" >total_living_area</th>
#                         <td id="T_3600c6a6_1cba_11eb_b63a_5c879ca494carow3_col0" class="data row3 col0" >0.69</td>
#                         <td id="T_3600c6a6_1cba_11eb_b63a_5c879ca494carow3_col1" class="data row3 col1" >0.63</td>
#                         <td id="T_3600c6a6_1cba_11eb_b63a_5c879ca494carow3_col2" class="data row3 col2" >0.32</td>
#                         <td id="T_3600c6a6_1cba_11eb_b63a_5c879ca494carow3_col3" class="data row3 col3" >1.00</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# #### Present histogram of selected features

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

df2.hist(bins=50, figsize=(15,15))
plt.show()

# %% [markdown]
# #### Present histogram of year built

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
df_yearblt = df2.year_built

df_yearblt.hist(bins=50, figsize=(15,15))
plt.show()

# %% [markdown]
# ### Export the prepared data

# %% [markdown]
# #### Export the dataframe that was prepared for regression

# %%
export_to_csv(df2,overwrite=True,export_location="./data/prepared-data.csv")
